# %%
import pandas as pd
import requests as req
from bs4 import BeautifulSoup
from datetime import datetime

# %%
data = []

for page in range(1, 43):
    # YES24 베스트셀러 페이지 URL(1페이지)
    url = f"https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber={page}&pageSize=24"

    # 웹 요청시 차단 방비 agent 추가
    headers = {"User_Agent": "Mozilla/5.0"}
    res = req.get(url, headers=headers)

    # 응답 확인
    if res.status_code == 200:
        soup = BeautifulSoup(res.text, "html.parser")

        book_titles = soup.select(".gd_name")
        book_prices = soup.select("strong > em")
        book_authors = soup.select("span.authPub.info_auth > a:nth-child(1)")
        book_publisher = soup.select("span.authPub.info_pub > a")
        book_sells = soup.select("span.saleNum")
        book_reviews = soup.select("span.rating_rvCount > a > em.txC_blue")
        book_stars = soup.select("span.rating_grade > em")

        books = zip(book_titles, book_prices, book_authors, book_publisher, book_sells, book_reviews, book_stars)

        for idx, (title, price, author, publisher, sell, review, star) in enumerate(books, start=1):        

            data.append({"title" : title.get_text(), "price": price.get_text(), "author": author.get_text(),
                        "publisher": publisher.get_text(), "sell": sell.get_text().split("수 ")[1].strip(),
                        "review": review.get_text(), "star": star.get_text()})

        print(f"{page} is Done! --- {datetime.now().strftime("%Y-%M-%D %H:%M:%S")}")

    else:
        print(f"요청 실패: {res.status_code}")

df = pd.DataFrame(data)
df
# Out:
# 1 is Done! --- 2025-06-03/12/25 15:06:14
# 2 is Done! --- 2025-06-03/12/25 15:06:15
# 3 is Done! --- 2025-06-03/12/25 15:06:16
# 4 is Done! --- 2025-06-03/12/25 15:06:16
# 5 is Done! --- 2025-06-03/12/25 15:06:17
# 6 is Done! --- 2025-06-03/12/25 15:06:18
# 7 is Done! --- 2025-06-03/12/25 15:06:19
# 8 is Done! --- 2025-06-03/12/25 15:06:20
# 9 is Done! --- 2025-06-03/12/25 15:06:20
# 10 is Done! --- 2025-06-03/12/25 15:06:21
# 11 is Done! --- 2025-06-03/12/25 15:06:22
# 12 is Done! --- 2025-06-03/12/25 15:06:23
# 13 is Done! --- 2025-06-03/12/25 15:06:24
# 14 is Done! --- 2025-06-03/12/25 15:06:25
# 15 is Done! --- 2025-06-03/12/25 15:06:25
# 16 is Done! --- 2025-06-03/12/25 15:06:26
# 17 is Done! --- 2025-06-03/12/25 15:06:27
# 18 is Done! --- 2025-06-03/12/25 15:06:28
# 19 is Done! --- 2025-06-03/12/25 15:06:28
# 20 is Done! --- 2025-06-03/12/25 15:06:29
# 21 is Done! --- 2025-06-03/12/25 15:06:30
# 22 is Done! --- 2025-06-03/12/25 15:06:31
# 23 is Done! --- 2025-06-03/12/25 15:06:32
# 24 is Done! --- 2025-06-03/12/25 15:06:32
# 25 is Done! --- 2025-06-03/12/25 15:06:33
# 26 is Done! --- 2025-06-03/12/25 15:06:34
# 27 is Done! --- 2025-06-03/12/25 15:06:35
# 28 is Done! --- 2025-06-03/12/25 15:06:35
# 29 is Done! --- 2025-06-03/12/25 15:06:36
# 30 is Done! --- 2025-06-03/12/25 15:06:37
# 31 is Done! --- 2025-06-03/12/25 15:06:38
# 32 is Done! --- 2025-06-03/12/25 15:06:39
# 33 is Done! --- 2025-06-03/12/25 15:06:39
# 34 is Done! --- 2025-06-03/12/25 15:06:40
# 35 is Done! --- 2025-06-03/12/25 15:06:41
# 36 is Done! --- 2025-06-03/12/25 15:06:42
# 37 is Done! --- 2025-06-03/12/25 15:06:43
# 38 is Done! --- 2025-06-03/12/25 15:06:43
# 39 is Done! --- 2025-06-03/12/25 15:06:44
# 40 is Done! --- 2025-06-03/12/25 15:06:45
# 41 is Done! --- 2025-06-03/12/25 15:06:46
# 42 is Done! --- 2025-06-03/12/25 15:06:47
#                                           title   price      author  \
# 0                                           스토너  15,120      존 윌리엄스
# 1                                        소년이 온다  13,500          한강
# 2                                      초역 부처의 말  16,020    코이케 류노스케
# 3                                        듀얼 브레인  18,900       이선 몰릭
# 4    2025 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상  14,850         최태성
# ..                                          ...     ...         ...
# 893                     2026 해커스경찰 박철한 경찰헌법 기본서  36,000         박철한
# 894                                   열린 사고와 표현  20,000  글쓰기교재편찬위원회
# 895                         혼자서도 잘하는 첫  한글 쓰기 1   6,750         김희정
# 896                             타키 포오 코믹 어드벤처 7  13,050       캐릭온TV
# 897                      YBM 실전토익 RC 1000 Vol.1  15,300         문동균
#
#            publisher       sell review  star
# 0       알에이치코리아(RHK)    276,306    457   9.3
# 1                 창비  3,021,624  3,749   9.7
# 2             포레스트북스    524,262    311   9.5
# 3              상상스퀘어     89,325      2  10.0
# 4              이투스북     260,139     45   9.6
# ..               ...        ...    ...   ...
# 893            해커스경찰     10,992     19  10.0
# 894            인문과교양      4,608      4  10.0
# 895             길벗스쿨     16,005     36  10.0
# 896  대원씨아이(단행)(대원키즈)     25,482     36   9.9
# 897        YBM(와이비엠)     11,712      3  10.0
#
# [898 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      898 non-null    object
#  1   price      898 non-null    object
#  2   author     898 non-null    object
#  3   publisher  898 non-null    object
#  4   sell       898 non-null    object
#  5   review     898 non-null    object
#  6   star       898 non-null    object
# dtypes: object(7)
# memory usage: 49.2+ KB

# %%
# YES24 베스트셀러 페이지 URL(1페이지)
url = "https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber=1&pageSize=24"

# 웹 요청시 차단 방비 agent 추가
headers = {"User_Agent": "Mozilla/5.0"}
res = req.get(url, headers=headers)

# 응답 확인
if res.status_code == 200:
    soup = BeautifulSoup(res.text, "html.parser")
    # <a class="gd_name" href="/Product/Goods/13137546" onclick="wiseLogV2(&#39;BS&#39;, &#39;001_005_001&#39;, &#39;&#39;); ">소년이 온다</a>
    
    book_titles = soup.select(".gd_name")

    for idx, title in enumerate(book_titles, start=1):
        book_prices = soup.select_one(f"#yesBestList > li:nth-child({idx}) > div > div.item_info > div.info_row.info_price > strong > em")
        book_authors = soup.select_one(f"#yesBestList > li:nth-child({idx}) > div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_auth > a:nth-child(1)")
        book_publisher = soup.select_one(f"#yesBestList > li:nth-child({idx}) > div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_pub > a")
        book_sells = soup.select_one(f"#yesBestList > li:nth-child({idx}) > div > div.item_info > div.info_row.info_rating > span.saleNum")
        book_reviews = soup.select_one(f"#yesBestList > li:nth-child({idx}) > div > div.item_info > div.info_row.info_rating > span.rating_rvCount > a > em.txC_blue")
        book_stars = soup.select_one(f"#yesBestList > li:nth-child({idx}) > div > div.item_info > div.info_row.info_rating > span.rating_grade > em")
        book_dates = soup.select_one(f"#yesBestList > li:nth-child({idx}) > div > div.item_info > div.info_row.info_pubGrp > span.authPub.info_date")
        
        if book_dates:
            print(f"{idx}: {title.get_text(strip=True)} : {book_prices.get_text()}원")
            print(f"저자: {book_authors.get_text()}, 출판사: {book_publisher.get_text()}, 출판일: {book_dates.get_text()}")
            print(f"판매량: {book_sells.get_text().strip()}, 리뷰수: {book_reviews.get_text()}, 별점: {book_stars.get_text()}\n")
        else:
            print(f"{idx}: {title.get_text(strip=True)} : {book_prices.get_text()}원")
            print(f"저자: {book_authors.get_text()}, 출판사: {book_publisher.get_text()}")
            print(f"판매량: {book_sells.get_text().strip()}, 리뷰수: {book_reviews.get_text()}, 별점: {book_stars.get_text()}\n")

else:
    print(f"요청 실패: {res.status_code}")

# %%
data = []

for i in range(1, 43):
    # YES24 베스트셀러 페이지 URL(1페이지)
    url = f"https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber={i}&pageSize=24"

    # 웹 요청시 차단 방비 agent 추가
    headers = {"User_Agent": "Mozilla/5.0"}
    res = req.get(url, headers=headers)

    # 응답 확인
    if res.status_code == 200:
        soup = BeautifulSoup(res.text, "html.parser")

        book_titles = soup.select(".gd_name")
        book_prices = soup.select("strong > em")
        book_authors = soup.select("span.authPub.info_auth > a:nth-child(1)")
        book_publisher = soup.select("span.authPub.info_pub > a")
        book_sells = soup.select("span.saleNum")
        book_reviews = soup.select("span.rating_rvCount > a > em.txC_blue")
        book_stars = soup.select("span.rating_grade > em")

        books = zip(book_titles, book_prices, book_authors, book_publisher, book_sells, book_reviews, book_stars)

        for idx, (title, price, author, publisher, sell, review, star) in enumerate(books, start=1):        

            data.append({"title" : title.get_text(), "price": price.get_text(), "author": author.get_text(),
                        "publisher": publisher.get_text(), "sell": sell.get_text().split("수 ")[1].strip(),
                        "review": review.get_text(), "star": star.get_text()})

    else:
        print(f"요청 실패: {res.status_code}")


df = pd.DataFrame(data)
df
# Out:
#                                           title   price      author  \
# 0                                           스토너  15,120      존 윌리엄스
# 1                                        소년이 온다  13,500          한강
# 2                                      초역 부처의 말  16,020    코이케 류노스케
# 3                                        듀얼 브레인  18,900       이선 몰릭
# 4    2025 큰별쌤 최태성의 별별한국사 한국사능력검정시험 심화(1,2,3급) 상  14,850         최태성
# ..                                          ...     ...         ...
# 893                     2026 해커스경찰 박철한 경찰헌법 기본서  36,000         박철한
# 894                                   열린 사고와 표현  20,000  글쓰기교재편찬위원회
# 895                         혼자서도 잘하는 첫  한글 쓰기 1   6,750         김희정
# 896                             타키 포오 코믹 어드벤처 7  13,050       캐릭온TV
# 897                      YBM 실전토익 RC 1000 Vol.1  15,300         문동균
#
#            publisher       sell review  star
# 0       알에이치코리아(RHK)    276,306    457   9.3
# 1                 창비  3,021,624  3,749   9.7
# 2             포레스트북스    524,262    311   9.5
# 3              상상스퀘어     89,325      2  10.0
# 4              이투스북     260,139     45   9.6
# ..               ...        ...    ...   ...
# 893            해커스경찰     10,992     19  10.0
# 894            인문과교양      4,608      4  10.0
# 895             길벗스쿨     16,005     36  10.0
# 896  대원씨아이(단행)(대원키즈)     25,482     36   9.9
# 897        YBM(와이비엠)     11,712      3  10.0
#
# [898 rows x 7 columns]

# %%
data_kyo = []
i = 1

while True:
    url = f"https://search.kyobobook.co.kr/search?keyword=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&target=total&gbCode=TOT&page={i}"

    # 웹 요청시 차단 방비 agent 추가
    headers = {"User-Agent": "Mozilla/5.0"}
    res = req.get(url, headers=headers)

    if res.status_code == 200:
        soup = BeautifulSoup(res.text, "html.parser")

        for j in range(1, 21):
            title = soup.select_one(f"#shopData_list > ul > li:nth-child({j}) > div.prod_area.horizontal > div.prod_info_box > div.auto_overflow_wrap.prod_name_group > div.auto_overflow_contents > div > a span:nth-child(2)")
            price = soup.select_one(f"#shopData_list > ul > li:nth-child({j}) > div.prod_area.horizontal > div.prod_info_box > div.prod_price > span.price > span.val")

            if title and price:
                data_kyo.append({"title": title.get_text(strip=True), "price": price.get_text(strip=True)})

        print(f"Page {i} is Done!")
        i += 1

    else:
        print("End!")
        break

df2 = pd.DataFrame(data_kyo)
df2
# Out:
# Page 1 is Done!
# Page 2 is Done!
# Page 3 is Done!
# Page 4 is Done!
# Page 5 is Done!
# Page 6 is Done!
# Page 7 is Done!
# Page 8 is Done!
# Page 9 is Done!
# Page 10 is Done!
# Page 11 is Done!
# Page 12 is Done!
# Page 13 is Done!
# Page 14 is Done!
# Page 15 is Done!
# Page 16 is Done!
# Page 17 is Done!
# Page 18 is Done!
# Page 19 is Done!
# Page 20 is Done!
# Page 21 is Done!
# Page 22 is Done!
# Page 23 is Done!
# Page 24 is Done!
# Page 25 is Done!
# Page 26 is Done!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 16
#      14 for j in range(1, 21):
#      15     title = soup.select_one(f"#shopData_list > ul > li:nth-child({j}) > div.prod_area.horizontal > div.prod_info_box > div.auto_overflow_wrap.prod_name_group > div.auto_overflow_contents > div > a span:nth-child(2)")
# ---> 16     price = soup.select_one(f"#shopData_list > ul > li:nth-child({j}) > div.prod_area.horizontal > div.prod_info_box > div.prod_price > span.price > span.val")
#      18     if title and price:
#      19         data_kyo.append({"title": title.get_text(strip=True), "price": price.get_text(strip=True)})
#
# File c:\Users\human\anaconda3\envs\test\Lib\site-packages\bs4\element.py:2094, in Tag.select_one(self, selector, namespaces, **kwargs)
#    2078 def select_one(self, selector, namespaces=None, **kwargs):
#    2079     """Perform a CSS selection operation on the current element.
#    2080
#    2081     :param selector: A CSS selector.
#    (...)   2092     :rtype: bs4.element.Tag
#    2093     """
# -> 2094     return self.css.select_one(selector, namespaces, **kwargs)
#
# File c:\Users\human\anaconda3\envs\test\Lib\site-packages\bs4\css.py:128, in CSS.select_one(self, select, namespaces, flags, **kwargs)
#     103 def select_one(self, select, namespaces=None, flags=0, **kwargs):
#     104     """Perform a CSS selection operation on the current Tag and return the
#     105     first result.
#     106
#    (...)    126
#     127     """
# --> 128     return self.api.select_one(
#     129         select, self.tag, self._ns(namespaces, select), flags, **kwargs
#     130     )
#
# File c:\Users\human\anaconda3\envs\test\Lib\site-packages\soupsieve\__init__.py:132, in select_one(select, tag, namespaces, flags, custom, **kwargs)
#     121 def select_one(
#     122     select: str,
#     123     tag: bs4.Tag,
#    (...)    128     **kwargs: Any
#     129 ) -> bs4.Tag:
#     130     """Select a single tag."""
# --> 132     return compile(select, namespaces, flags, **kwargs).select_one(tag)
#
# File c:\Users\human\anaconda3\envs\test\Lib\site-packages\soupsieve\css_match.py:1558, in SoupSieve.select_one(self, tag)
#    1555 def select_one(self, tag: bs4.Tag) -> bs4.Tag:
#    1556     """Select a single tag."""
# -> 1558     tags = self.select(tag, limit=1)
#    1559     return tags[0] if tags else None
#
# File c:\Users\human\anaconda3\envs\test\Lib\site-packages\soupsieve\css_match.py:1564, in SoupSieve.select(self, tag, limit)
#    1561 def select(self, tag: bs4.Tag, limit: int = 0) -> list[bs4.Tag]:
#    1562     """Select the specified tags."""
# -> 1564     return list(self.iselect(tag, limit))
#
# File c:\Users\human\anaconda3\envs\test\Lib\site-packages\soupsieve\css_match.py:1569, in SoupSieve.iselect(self, tag, limit)
#    1566 def iselect(self, tag: bs4.Tag, limit: int = 0) -> Iterator[bs4.Tag]:
#    1567     """Iterate the specified tags."""
# -> 1569     yield from CSSMatch(self.selectors, tag, self.namespaces, self.flags).select(limit)
#
# File c:\Users\human\anaconda3\envs\test\Lib\site-packages\soupsieve\css_match.py:1469, in CSSMatch.select(self, limit)
#    1466 lim = None if limit < 1 else limit
#    1468 for child in self.get_descendants(self.tag):
# -> 1469     if self.match(child):
#    1470         yield child
#    1471         if lim is not None:
#
# File c:\Users\human\anaconda3\envs\test\Lib\site-packages\soupsieve\css_match.py:1496, in CSSMatch.match(self, el)
#    1493 def match(self, el: bs4.Tag) -> bool:
#    1494     """Match."""
# -> 1496     return not self.is_doc(el) and self.is_tag(el) and self.match_selectors(el, self.selectors)
#
# File c:\Users\human\anaconda3\envs\test\Lib\site-packages\soupsieve\css_match.py:1400, in CSSMatch.match_selectors(self, el, selectors)
#    1398     continue
#    1399 # Verify tag matches
# -> 1400 if not self.match_tag(el, selector.tag):
#    1401     continue
#    1402 # Verify tag is defined
#
# File c:\Users\human\anaconda3\envs\test\Lib\site-packages\soupsieve\css_match.py:753, in CSSMatch.match_tag(self, el, tag)
#     747     name = (util.lower(tag.name) if not self.is_xml and tag.name is not None else tag.name)
#     748     return not (
#     749         name is not None and
#     750         name not in (self.get_tag(el), '*')
#     751     )
# --> 753 def match_tag(self, el: bs4.Tag, tag: ct.SelectorTag | None) -> bool:
#     754     """Match the tag."""
#     756     match = True
#
# KeyboardInterrupt:

# %%
data_kyo = []
i = 1
soup = []

while True:
    url = f"https://search.kyobobook.co.kr/search?keyword=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&target=total&gbCode=TOT&page={i}"

    # 웹 요청시 차단 방비 agent 추가
    headers = {"User-Agent": "Mozilla/5.0"}
    res = req.get(url, headers=headers)

    if res.status_code == 200:
        soup.append(BeautifulSoup(res.text, "html.parser"))
        print(f"Page {i} is Done!")
        i += 1

    else:
        print("End!")
        break

for data in soup:
    for j in range(1, 21):
        title = data.select_one(f"#shopData_list > ul > li:nth-child({j}) > div.prod_area.horizontal > div.prod_info_box > div.auto_overflow_wrap.prod_name_group > div.auto_overflow_contents > div > a span:nth-child(2)")
        price = data.select_one(f"#shopData_list > ul > li:nth-child({j}) > div.prod_area.horizontal > div.prod_info_box > div.prod_price > span.price > span.val")

        if title and price:
            data_kyo.append({"title": title.get_text(strip=True), "price": price.get_text(strip=True)})


df2 = pd.DataFrame(data_kyo)
df2
