# %% [markdown]
# ## Colab 환경에서 실행 시 환경 설정

# %%
# 구글 드라이브의 폴더와 구글 코랩 폴더 연결
from google.colab import drive
drive.mount('/content/drive')

# %%
# 현재 경로 확인
# !pwd

# %%
# drive/MyDrive/Colab Notebooks 경로로 변경
# %cd drive/MyDrive/'Colab Notebooks'

# %% [markdown]
# #### 코랩에서 한국어 표시하기

# %%
# !pip install koreanize-matplotlib

# %%
import koreanize_matplotlib

# %% [markdown]
# # 🔖 Fine-tuning 그리고 AI 추론 API 만들기

# %% [markdown]
# ### 🎯 최종 결과물

# %% [markdown]
# <img src="data:image/png;base64,..." width="600" height="400"/>

# %% [markdown]
# #### ✅ 사용자 얼굴 이미지 입력 <br>
# #### 🔍 얼굴 감지 (Object Detection) <br>
# #### 😊 감정 분석 (Emotion Recognition) <br>

# %% [markdown]
# <a id="lecture_index"></a>
# ## 수업 목차
#
# [1. Hugging Face로 배우는 Fine-tuning](#one)<br>
# - 감정 인식 모델을 내 데이터에 맞게 조정하기
#
# [2. FastAPI로 배우는 AI API 개발](#two)<br>
# - 얼굴 이미지 받기 + 감정 예측, 얼굴 위치 결과 반환
#
# [3. Streamlit을 활용한 화면 구성](#three)<br>
# - 이미지 업로드 + 결과 이미지 확인 기능

# %% [markdown]
# ## <a id='two'>1️⃣ Hugging Face로 배우는 Fine-tuning</a><br>

# %% [markdown]
# <a href="#lecture_index">
#     <span>⬆ 목차로</span>
# </a>

# %% [markdown]
# ## Huggingface transformers
#
# > 사전학습된 최신 NLP 모델을 쉽게 불러와 다양한 자연어 처리 작업에 활용하고, fine-tuning까지 간편하게 수행할 수 있게 해주는 고수준 라이브러리 <br>
# > 🛠️ 초기에는 NLP특화로 시작했지만, 현재는 멀티모달, 이미지, 오디오, 등 다양한 모델 및 데이터를 지원하고 있음

# %% [markdown]
# 참고: https://huggingface.co/docs/transformers/ko/index

# %% [markdown]
# ## 이미지 분류 모델 Fine tuning

# %% [markdown]
# ### 기본 구조

# %% [markdown]
# | 클래스명  | 역할 |
# | -------- | ----------- |
# | AutoImageProcessor| 사전학습된 이미지 전처리를 도와주는 클래스 |
# | AutoModelForImageClassification | 사전학습된 이미지 분류 모델 클래스
# | Trainer | 학습, 평가, 저장 자동화 도구 |

# %% [markdown]
# ### 사전학습 모델 불러오기

# %%
from transformers import AutoImageProcessor, AutoModelForImageClassification

model_name = "gerhardien/face-emotion"

# %% [markdown]
# ### 추론하기

# %% [markdown]
# ### Fine-tuning 설정하기

# %%
from transformers import AutoImageProcessor, AutoModelForImageClassification

# %% [markdown]
# ### 데이터셋 구성하기

# %% [markdown]
# ### 평가지표 설정하기

# %% [markdown]
# ### 학습 루프 설정하기

# %% [markdown]
# ### 모델 저장하기

# %% [markdown]
# ## 텍스트 분류 모델 Fine tuning

# %% [markdown]
# ### 기본 구조
#
# | 개념          | 역할                                                                              |
# | ----------- | -------------------------------------------------------------------------------- |
# | `AutoTokenizer` | 텍스트를 모델 입력용 토큰 ID로 변환해주는 전처리 클래스  |
# | `AutoModelForSeq2SeqLM`     |  텍스트 생성, 요약 클래스 |
# | `Trainer`   | 학습, 평가, 저장 자동화 도구 |

# %% [markdown]
# ### 사전학습 모델 불러오기

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_name = "csebuetnlp/mT5_multilingual_XLSum"

# %% [markdown]
# ### 추론하기

# %% [markdown]
# ### Fine-tuning 설정하기

# %% [markdown]
# ### 데이터셋 구성하기

# %% [markdown]
# ### 평가지표 설정하기

# %% [markdown]
# ### 학습 루프 설정하기

# %% [markdown]
# ### 모델 저장하기
